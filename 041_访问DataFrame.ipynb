# %%
#1.访问某列或某几列
#2.访问某行或某几行
#3.筛选出满足条件的行
import pandas as pd 
df_imdb = pd.read_csv('IMDB-Movie-Data.csv')
df_imdb
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df_imdb.iloc[:,1]  # 显示title列
# Out:
# 0      Guardians of the Galaxy
# 1                   Prometheus
# 2                        Split
# 3                         Sing
# 4                Suicide Squad
#                 ...
# 995       Secret in Their Eyes
# 996            Hostel: Part II
# 997     Step Up 2: The Streets
# 998               Search Party
# 999                 Nine Lives
# Name: Title, Length: 1000, dtype: object

# %%
df_imdb.loc[:, 'Title']  # 另一种方法
# Out:
# 0      Guardians of the Galaxy
# 1                   Prometheus
# 2                        Split
# 3                         Sing
# 4                Suicide Squad
#                 ...
# 995       Secret in Their Eyes
# 996            Hostel: Part II
# 997     Step Up 2: The Streets
# 998               Search Party
# 999                 Nine Lives
# Name: Title, Length: 1000, dtype: object

# %%
df_imdb.iloc[:, :3]  # 访问前三列
# Out:
#      Rank                    Title                     Genre
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
# [1000 rows x 3 columns]

# %%
df_imdb.loc[:, ['Rank', 'Title', 'Genre']] #  显示前三列 另一种方法
# Out:
#      Rank                    Title                     Genre
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
# [1000 rows x 3 columns]

# %%
df_imdb.iloc[0]  #  显示第一行
# Out:
# Rank                                                                  1
# Title                                           Guardians of the Galaxy
# Genre                                           Action,Adventure,Sci-Fi
# Description           A group of intergalactic criminals are forced ...
# Director                                                     James Gunn
# Actors                Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# Year                                                               2014
# Runtime (Minutes)                                                   121
# Rating                                                              8.1
# Votes                                                            757074
# Revenue (Millions)                                               333.13
# Metascore                                                          76.0
# Name: 0, dtype: object

# %%
df_imdb.loc[0]  #另一种办法
# Out:
# Rank                                                                  1
# Title                                           Guardians of the Galaxy
# Genre                                           Action,Adventure,Sci-Fi
# Description           A group of intergalactic criminals are forced ...
# Director                                                     James Gunn
# Actors                Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# Year                                                               2014
# Runtime (Minutes)                                                   121
# Rating                                                              8.1
# Votes                                                            757074
# Revenue (Millions)                                               333.13
# Metascore                                                          76.0
# Name: 0, dtype: object

# %%
df_imdb.iloc[5:10]  # 5到10行
# Out:
#    Rank               Title                       Genre  \
# 5     6      The Great Wall    Action,Adventure,Fantasy
# 6     7          La La Land          Comedy,Drama,Music
# 7     8            Mindhorn                      Comedy
# 8     9  The Lost City of Z  Action,Adventure,Biography
# 9    10          Passengers     Adventure,Drama,Romance
#
#                                          Description         Director  \
# 5  European mercenaries searching for black powde...      Yimou Zhang
# 6  A jazz pianist falls for an aspiring actress i...  Damien Chazelle
# 7  A has-been actor best known for playing the ti...       Sean Foley
# 8  A true-life drama, centering on British explor...       James Gray
# 9  A spacecraft traveling to a distant colony pla...    Morten Tyldum
#
#                                               Actors  Year  Runtime (Minutes)  \
# 5      Matt Damon, Tian Jing, Willem Dafoe, Andy Lau  2016                103
# ...

# %%
df_imdb.loc[5:10]  # 另一种方法
# Out:
#     Rank                                    Title                       Genre  \
# 5      6                           The Great Wall    Action,Adventure,Fantasy
# 6      7                               La La Land          Comedy,Drama,Music
# 7      8                                 Mindhorn                      Comedy
# 8      9                       The Lost City of Z  Action,Adventure,Biography
# 9     10                               Passengers     Adventure,Drama,Romance
# 10    11  Fantastic Beasts and Where to Find Them    Adventure,Family,Fantasy
#
#                                           Description         Director  \
# 5   European mercenaries searching for black powde...      Yimou Zhang
# 6   A jazz pianist falls for an aspiring actress i...  Damien Chazelle
# 7   A has-been actor best known for playing the ti...       Sean Foley
# 8   A true-life drama, centering on British explor...       James Gray
# ...

# %%
df_imdb[df_imdb['Year']==2014]
# Out:
#      Rank                         Title                    Genre  \
# 0       1       Guardians of the Galaxy  Action,Adventure,Sci-Fi
# 36     37                  Interstellar   Adventure,Drama,Sci-Fi
# 53     54                     John Wick    Action,Crime,Thriller
# 65     66  Kingsman: The Secret Service  Action,Adventure,Comedy
# 83     84                     Gone Girl      Crime,Drama,Mystery
# ..    ...                           ...                      ...
# 981   982                         Annie      Comedy,Drama,Family
# 983   984                 Let's Be Cops                   Comedy
# 987   988                  Endless Love            Drama,Romance
# 989   990                         Selma  Biography,Drama,History
# 998   999                  Search Party         Adventure,Comedy
#
#                                            Description           Director  \
# 0    A group of intergalactic criminals are forced ...         James Gunn
# ...

# %%
df2 = df_imdb[(df_imdb['Year']==2014) & (df_imdb['Rating'] > 7.0)]
df2.shape
# Out:
# (41, 12)

# %%
df2
# Out:
#      Rank                                            Title  \
# 0       1                          Guardians of the Galaxy
# 36     37                                     Interstellar
# 53     54                                        John Wick
# 65     66                     Kingsman: The Secret Service
# 83     84                                        Gone Girl
# 109   110                                       Ex Machina
# 133   134                                         Whiplash
# 154   155                   Twin Peaks: The Missing Pieces
# 162   163                       X-Men: Days of Future Past
# 170   171                                     Nightcrawler
# 176   177                   Dawn of the Planet of the Apes
# 198   199                               The Imitation Game
# 200   201                                 Edge of Tomorrow
# 216   217              Captain America: The Winter Soldier
# 238   239                         The Grand Budapest Hotel
# ...
